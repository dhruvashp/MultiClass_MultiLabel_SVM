# %% [markdown]
# HW5
# b
# iii
#
# Again standardization will be performed only ONCE on the entire feature set (train + test)
#
# The range of C-values will be assumed same as obtained before (not technically correct, we need to perform range selection again, technically, but we'll make this assumption) (additionally as CV here is only done over C-values, we can pick a larger range automatically without worrying much about the computational factors)

# %%
import pandas as pd
import numpy as np
from sklearn.svm import SVC

df_train = pd.read_csv('Train_Data.csv',index_col=0)
df_test = pd.read_csv('Test_Data.csv',index_col=0)
print(df_train)
print(df_test)
# Out:
#       MFCCs_ 1  MFCCs_ 2  MFCCs_ 3  MFCCs_ 4  MFCCs_ 5  MFCCs_ 6  MFCCs_ 7  \
# 0          1.0  0.464912  0.409357  0.229967  0.043024  0.110648  0.041558
# 1          1.0  0.550581  0.416760  0.199992  0.029394  0.152047  0.088736
# 2          1.0  0.305720  0.161712  0.521877  0.148562 -0.035945 -0.138314
# 3          1.0  0.085629  0.194640  0.558177  0.288138  0.013115 -0.084558
# 4          1.0  0.157831  0.220788  0.662399  0.255485 -0.011588 -0.164573
# ...        ...       ...       ...       ...       ...       ...       ...
# 5031       1.0  0.948185  0.937043  0.430321  0.102723  0.398668 -0.067899
# 5032       1.0  0.324665  0.231543  0.658007  0.202736 -0.012427 -0.089231
# 5033       1.0  0.374609  0.134837  0.317741  0.105642  0.075624  0.158739
# 5034       1.0  0.782845  0.885191  0.356826 -0.067459  0.240009  0.098551
# 5035       1.0  0.044293  0.377297  0.421066  0.177453  0.209028  0.079516
#
#       MFCCs_ 8  MFCCs_ 9  MFCCs_10  ...  MFCCs_16  MFCCs_17  MFCCs_18  \
# 0    -0.009842  0.081414  0.036627  ...  0.078128  0.019938 -0.039470
# 1    -0.052387  0.079058  0.068792  ...  0.053192 -0.017401 -0.021349
# 2     0.042936  0.228264 -0.002935  ...  0.012772  0.204895  0.116231
# 3     0.256094  0.278833 -0.065600  ...  0.095579  0.101606 -0.037121
# 4     0.049777  0.233471 -0.029371  ...  0.308647  0.261579 -0.079429
# ...        ...       ...       ...  ...       ...       ...       ...
# 5031 -0.139194  0.251098  0.082581  ...  0.075853 -0.083334 -0.228895
# 5032  0.157379  0.335455 -0.070202  ...  0.157242  0.202260 -0.032797
# 5033  0.075226 -0.123655 -0.002919  ... -0.246365 -0.255364  0.028940
# 5034  0.044059  0.139555 -0.120770  ...  0.082305 -0.146501  0.007351
# 5035 -0.161934 -0.070339  0.069340  ... -0.014844  0.125412  0.054223
#
#       MFCCs_19  MFCCs_20  MFCCs_21  MFCCs_22  Family  Genus  Species
# 0    -0.000706 -0.005770  0.002200  0.056288       2      3        5
# 1     0.031531  0.001219  0.006335  0.054646       2      3        5
# 2    -0.028744 -0.184980  0.000807  0.250984       3      0        1
# 3    -0.009066 -0.029094  0.140035  0.108224       3      0        1
# 4    -0.192822 -0.045800  0.168129  0.179297       3      0        1
# ...        ...       ...       ...       ...     ...    ...      ...
# 5031  0.070537 -0.007341 -0.070222  0.110329       2      3        5
# 5032 -0.127551 -0.093905  0.025605  0.157339       3      0        1
# 5033  0.022588 -0.004840  0.047002  0.084752       1      1        2
# 5034  0.068298  0.123924  0.044961 -0.162249       2      3        4
# 5035 -0.021921  0.007565 -0.077424 -0.027695       2      3        5
#
# [5036 rows x 25 columns]
#       MFCCs_ 1  MFCCs_ 2  MFCCs_ 3  MFCCs_ 4  MFCCs_ 5  MFCCs_ 6  MFCCs_ 7  \
# 0          1.0  0.362366  0.174132  0.228056 -0.067992 -0.044878  0.162672
# 1          1.0  0.105913  0.333914  0.349876  0.172036  0.211248  0.147673
# 2          1.0  0.190421  0.219581  0.610626  0.196886  0.037638 -0.145008
# 3          1.0  0.057275  0.000756  0.458518  0.217470  0.091216 -0.055090
# 4          1.0  0.411629  0.318173  0.532519  0.181145  0.039846 -0.065335
# ...        ...       ...       ...       ...       ...       ...       ...
# 2154       1.0  0.403517  0.251328  0.555090  0.202856 -0.060089 -0.147158
# 2155       1.0 -0.117778  0.117083  0.333777  0.383093  0.179308 -0.149329
# 2156       1.0  0.184261  0.325371  0.315440  0.125807  0.176992  0.131400
# 2157       1.0  0.176501 -0.118110  0.262950  0.242768  0.071629 -0.050304
# 2158       1.0 -0.350154 -0.378308 -0.025907  0.006280  0.169734  0.275162
#
#       MFCCs_ 8  MFCCs_ 9  MFCCs_10  ...  MFCCs_16  MFCCs_17  MFCCs_18  \
# 0     0.073472 -0.151432 -0.050095  ... -0.102357 -0.112155  0.066174
# 1    -0.162151 -0.045324  0.093012  ...  0.002756  0.095784  0.044691
# 2     0.034531  0.299597  0.085203  ...  0.124965  0.182419 -0.029639
# 3     0.014044  0.259953  0.108505  ... -0.035656  0.228542  0.057019
# 4     0.074894  0.248024 -0.020991  ...  0.067832  0.127299 -0.028072
# ...        ...       ...       ...  ...       ...       ...       ...
# 2154  0.089691  0.281005  0.011497  ...  0.095638  0.255686  0.075666
# 2155 -0.056769  0.016896  0.095274  ...  0.069237  0.032612  0.024816
# 2156 -0.120158 -0.064537  0.083073  ... -0.005127  0.104220  0.070151
# 2157  0.005639  0.122420  0.087915  ... -0.093008 -0.188559 -0.042996
# 2158  0.129003  0.199270  0.150783  ...  0.019372  0.150814  0.107573
#
#       MFCCs_19  MFCCs_20  MFCCs_21  MFCCs_22  Family  Genus  Species
# 0    -0.015691 -0.114416 -0.041460  0.011978       1      1        2
# 1     0.017000 -0.019220 -0.064557 -0.044979       2      3        5
# 2    -0.150117 -0.158192  0.025760  0.181372       3      0        1
# 3    -0.154582 -0.182062  0.015546  0.246162       3      0        1
# 4    -0.069316 -0.069892  0.098817  0.232463       3      0        1
# ...        ...       ...       ...       ...     ...    ...      ...
# 2154 -0.055050 -0.101619  0.030767  0.189878       3      0        1
# 2155 -0.018284 -0.026578 -0.007603  0.015087       2      7        9
# 2156  0.022908 -0.011797 -0.045775 -0.016815       2      3        5
# 2157  0.062674 -0.018801 -0.085252  0.087206       1      1        2
# 2158 -0.014363 -0.072600 -0.039651  0.017255       2      2        3
#
# [2159 rows x 25 columns]

# %%
features_train = df_train.drop(columns=['Family','Genus','Species'])
features_test = df_test.drop(columns=['Family','Genus','Species']) 

family_train = pd.DataFrame(df_train['Family'])
genus_train = pd.DataFrame(df_train['Genus'])
#       MFCCs_16  MFCCs_17  MFCCs_18  MFCCs_19  MFCCs_20  MFCCs_21  MFCCs_22
# 0     0.300785 -0.497969 -0.557374  0.590837  0.504108 -0.441874 -0.253409
# 1     0.092822 -0.768448 -0.343508  0.981404  0.578327 -0.389841 -0.266717
# 2    -0.244272  0.841860  1.280293  0.251153 -1.398855 -0.459403  1.323923
# 3     0.446319  0.093634 -0.529656  0.489551  0.256442  1.292670  0.167350
# 4     2.223267  1.252475 -1.028995 -1.736716  0.079044  1.646218  0.743148
# ...        ...       ...       ...       ...       ...       ...       ...
# 7190  0.446817  1.209789  0.801523 -0.067561 -0.513674 -0.082377  0.828872
# 7191  0.226633 -0.406159  0.201360  0.377875  0.283153 -0.565238 -0.587200
# 7192 -0.393545  0.112572  0.736436  0.876935  0.440114 -1.045611 -0.845656
# 7193 -1.126457 -2.008312 -0.598994  1.358708  0.365734 -1.542390 -0.002927
# 7194 -0.189227  0.450099  1.178107  0.425384 -0.205533 -0.968541 -0.569641
#
# [7195 rows x 22 columns]

# %%
features_train = whole_features_scaled_df.iloc[0:features_train.shape[0],:]  # Updating features_train with standardized values
features_test = whole_features_scaled_df.iloc[features_train.shape[0]:,:] # Updating features_test with standardized values
features_train.reset_index(drop=True,inplace=True)
features_test.reset_index(drop=True,inplace=True)
print(features_train)
print(features_test)
# Out:
#       MFCCs_ 1  MFCCs_ 2  MFCCs_ 3  MFCCs_ 4  MFCCs_ 5  MFCCs_ 6  MFCCs_ 7  \
# 0     0.146578  0.646405  0.372409 -1.347526 -0.516392  0.105555  0.250624
# 1     0.146578  1.038234  0.400503 -1.534500 -0.600156  0.449393  0.525888
# 2     0.146578 -0.081705 -0.567388  0.473311  0.132235 -1.111961 -0.798852
# 3     0.146578 -1.088349 -0.442430  0.699740  0.990049 -0.704498 -0.485212
# 4     0.146578 -0.758117 -0.343201  1.349843  0.789366 -0.909663 -0.952065
# ...        ...       ...       ...       ...       ...       ...       ...
# 5031  0.146578  2.856782  2.374945 -0.097781 -0.149487  2.497679 -0.388012
# 5032  0.146578  0.004943 -0.302384  1.322447  0.465181 -0.916635 -0.512473
# 5033  0.146578  0.233375 -0.669377 -0.800018 -0.131548 -0.185339  0.934322
# 5034  0.146578  2.100553  2.178169 -0.556222 -1.195401  1.179951  0.583151
# 5035  0.146578 -1.277413  0.250741 -0.155511  0.309795  0.922641  0.472094
#
#       MFCCs_ 8  MFCCs_ 9  MFCCs_10  ...  MFCCs_13  MFCCs_14  MFCCs_15  \
# 0    -0.081450 -0.261453 -0.152415  ... -0.423725 -0.118861  0.366901
# 1    -0.447284 -0.274616  0.100667  ... -0.245736 -0.018215  0.501620
# 2     0.372386  0.558956 -0.463707  ...  0.897189 -0.042615 -0.847256
# 3     2.205311  0.841468 -0.956784  ...  0.719728 -0.136467 -0.367088
# 4     0.431209  0.588042 -0.671717  ...  0.398108 -1.213975 -0.140641
# ...        ...       ...       ...  ...       ...       ...       ...
# 5031 -1.193733  0.686519  0.209162  ... -0.811521 -0.282635  0.429766
# 5032  1.356466  1.157800 -0.992996  ...  1.398065 -0.883665 -1.090590
# 5033  0.650047 -1.407115 -0.463585  ... -1.509408  2.041688  1.683618
# 2157  0.051675 -0.032368  0.251137  ... -0.760055  2.088967  1.498704
# 2158  1.112464  0.396973  0.745809  ... -0.369802  0.396072  0.006039
#
#       MFCCs_16  MFCCs_17  MFCCs_18  MFCCs_19  MFCCs_20  MFCCs_21  MFCCs_22
# 0    -1.204423 -1.454850  0.689497  0.409294 -0.649565 -0.991307 -0.612393
# 1    -0.327806  0.051460  0.435944  0.805356  0.361294 -1.281971 -1.073834
# 2     0.691392  0.679039 -0.441346 -1.219328 -1.114410 -0.145394  0.759961
# 3    -0.648150  1.013155  0.581436 -1.273421 -1.367867 -0.273928  1.284860
# 4     0.214917  0.279749 -0.422855 -0.240391 -0.176775  0.773978  1.173881
# ...        ...       ...       ...       ...       ...       ...       ...
# 2154  0.446817  1.209789  0.801523 -0.067561 -0.513674 -0.082377  0.828872
# 2155  0.226633 -0.406159  0.201360  0.377875  0.283153 -0.565238 -0.587200
# 2156 -0.393545  0.112572  0.736436  0.876935  0.440114 -1.045611 -0.845656
# 2157 -1.126457 -2.008312 -0.598994  1.358708  0.365734 -1.542390 -0.002927
# 2158 -0.189227  0.450099  1.178107  0.425384 -0.205533 -0.968541 -0.569641
#
# [2159 rows x 22 columns]

# %%
print(family_train)
print(genus_train)
print(species_train)
# Out:
#       Family
# 0          2
# 1          2
# 2          3
# 3          3
# 4          3
# ...      ...
# 5031       2
# 5032       3
# 5033       1
# 5034       2
# 5035       2
#
# [5036 rows x 1 columns]
#       Genus
# 0         3
# 1         3
# 2         0
# 3         0
# 4         0
# ...     ...
# 5031      3
# 5032      0
# 5033      1
# 5034      3
# 5035      3
#
# [5036 rows x 1 columns]
#       Species
# 0           5
# 1           5
# 2           1
# 3           1
# 4           1
# ...       ...
# 5031        5
# 5032        1
# 5033        2
# 5034        4
# 5035        5
#
# [5036 rows x 1 columns]

# %%
print(family_test)
print(genus_test)
print(species_test)
# Out:
#       Family
# 0          1
# 1          2
# 2          3
# 3          3
# 4          3
# ...      ...
# 2154       3
# 2155       2
# 2156       2
# 2157       1
# 2158       2
#
# [2159 rows x 1 columns]
#       Genus
# 0         1
# 1         3
# 2         0
# 3         0
# 4         0
# ...     ...
# 2154      0
# 2155      7
# 2156      3
# 2157      1
# 2158      2
#
# [2159 rows x 1 columns]
#       Species
# 0           2
# 1           5
# 2           1
# 3           1
# 4           1
# ...       ...
# 2154        1
# 2155        9
# 2156        5
# 2157        2
# 2158        3
#
# [2159 rows x 1 columns]

# %%
from sklearn.model_selection import KFold
from sklearn.svm import LinearSVC
import warnings
warnings.filterwarnings('ignore')
kf = KFold(n_splits=10,shuffle=True)  # 10-fold CV
C = np.array([10**(-4),10**(-3),10**(-2),10**(-1),10**(0),10**1,10**2,10**3,10**4,10**5,10**6,10**7,10**8])

CV_errors = pd.DataFrame(index=C,columns=['Errors in %'])

for i in np.arange(0,C.size):
    cv_ite = -1
    
    cv_loc_err = np.zeros(10)
    
    for train, test in kf.split(features_train):
            cv_ite = cv_ite + 1
            X_train,X_test = features_train.iloc[train,:],features_train.iloc[test,:]
            yf_train,yf_test = family_train.iloc[train,:],family_train.iloc[test,:]
            yg_train,yg_test = genus_train.iloc[train,:],genus_train.iloc[test,:]
            ys_train,ys_test = species_train.iloc[train,:],species_train.iloc[test,:]
            
            clf_f = LinearSVC(penalty='l1',C=C[i],multi_class='ovr',dual=False).fit(X_train,yf_train)
            clf_g = LinearSVC(penalty='l1',C=C[i],multi_class='ovr',dual=False).fit(X_train,yg_train)
            clf_s = LinearSVC(penalty='l1',C=C[i],multi_class='ovr',dual=False).fit(X_train,ys_train)
            
            yf_pred_test = clf_f.predict(X_test)
            yg_pred_test = clf_g.predict(X_test)
            ys_pred_test = clf_s.predict(X_test)
            
            mis = 0
            
            for k in np.arange(0,X_test.shape[0]):
                if yf_pred_test[k] != yf_test.iloc[k,0]:
                    mis = mis + 1
                    
                if yg_pred_test[k] != yg_test.iloc[k,0]:
                    mis = mis + 1
                    
                if ys_pred_test[k] != ys_test.iloc[k,0]:
                    mis = mis + 1
            
            
            mis_percentage = (mis/(3*X_test.shape[0]))*100
            
            
            cv_loc_err[cv_ite] = mis_percentage
            
        
        
    CV_errors.iloc[i,0] = np.mean(cv_loc_err)

    
print(CV_errors)
# Out:
#              Errors in %
# 1.000000e-04     77.2773
# 1.000000e-03     18.6326
# 1.000000e-02     8.51873
# 1.000000e-01      6.2148
# 1.000000e+00     5.71195
# 1.000000e+01     5.61959
# 1.000000e+02     5.51374
# 1.000000e+03     5.62602
# 1.000000e+04     5.53322
# 1.000000e+05     5.61288
# 1.000000e+06     5.57306
# 1.000000e+07     5.71164
# 1.000000e+08     5.69256

# %%
CV_errors.to_csv('L1_CV_errors.csv') # saving to .csv for future reference

# %%
min_err = CV_errors.min(axis=0)
print('The minimum test error estimate obtained, averaged over 10 fold CV is : \n',min_err)
# Out:
# The minimum test error estimate obtained, averaged over 10 fold CV is :
#  Errors in %    5.513743
# dtype: float64

# %%
indx_min = np.argmin(CV_errors.to_numpy().flatten())
min_C = C[indx_min]
print('The C value that minimizes the test error estimate is : \n',min_C)
# Out:
# The C value that minimizes the test error estimate is :
#  100.0

# %% [markdown]
# Thus we obtain C=100 as the optimal value here, via 10-fold CV

# %% [markdown]
# Actual Test Error

# %%
clf_fam = LinearSVC(penalty='l1',C=min_C,multi_class='ovr',dual=False).fit(features_train,family_train)
clf_gen = LinearSVC(penalty='l1',C=min_C,multi_class='ovr',dual=False).fit(features_train,genus_train)
clf_spe = LinearSVC(penalty='l1',C=min_C,multi_class='ovr',dual=False).fit(features_train,species_train)


y_fam_pre = clf_fam.predict(features_test)
y_gen_pre = clf_gen.predict(features_test)
y_spe_pre = clf_spe.predict(features_test)

mis = 0
for i in np.arange(0,features_test.shape[0]):
    if y_fam_pre[i] != family_test.iloc[i,0]:
        mis = mis + 1
    if y_gen_pre[i] != genus_test.iloc[i,0]:
        mis = mis + 1
    if y_spe_pre[i] != species_test.iloc[i,0]:
        mis = mis + 1
    
test_error = (mis/(3*features_test.shape[0]))*100
print('The actual test error obtained with the optimized C is : \n',test_error,'%')
# Out:
# The actual test error obtained with the optimized C is :
#  4.724409448818897 %

# %% [markdown]
# Again, as expected, actual test error is a bit lower than the estimated one
